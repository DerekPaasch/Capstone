# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
Health_Status = pd.read_csv("../data/Health_Status_full_dataset.csv")
Health_Status.head()
# Out:
#         VAR                            Variable      UNIT  \
# 0  INJRACIR  Injuries in road traffic accidents  BLESSETX
# 1  INJRACIR  Injuries in road traffic accidents  BLESSETX
# 2  INJRACIR  Injuries in road traffic accidents  BLESSETX
# 3  INJRACIR  Injuries in road traffic accidents  BLESSETX
# 4  INJRACIR  Injuries in road traffic accidents  BLESSETX
#
#                           Measure  COU    Country   YEA  Year   Value  \
# 0  Injured per million population  AUS  Australia  2010  2010  1478.2
# 1  Injured per million population  AUS  Australia  2011  2011  1513.3
# 2  Injured per million population  AUS  Australia  2012  2012  1486.9
# 3  Injured per million population  AUS  Australia  2013  2013  1504.8
# 4  Injured per million population  AUS  Australia  2014  2014  1503.9
#
#   Flag Codes  Flags
# 0        NaN    NaN
# 1        NaN    NaN
# 2          B  Break
# 3        NaN    NaN
# 4        NaN    NaN

# %%
Determinants_of_health = pd.read_csv("../data/Determinants_of_health.csv")
Determinants_of_health.head()
# Out:
#         VAR          Variable      UNIT                   Measure  COU  \
# 0  FOODTFAT  Total fat supply  PROPERQT  Grams per capita per day  AUS
# 1  FOODTFAT  Total fat supply  PROPERQT  Grams per capita per day  AUS
# 2  FOODTFAT  Total fat supply  PROPERQT  Grams per capita per day  AUS
# 3  FOODTFAT  Total fat supply  PROPERQT  Grams per capita per day  AUS
# 4  FOODTFAT  Total fat supply  PROPERQT  Grams per capita per day  AUS
#
#      Country   YEA  Year  Value Flag Codes  Flags
# 0  Australia  2010  2010  151.3          B  Break
# 1  Australia  2011  2011  155.2        NaN    NaN
# 2  Australia  2012  2012  156.4        NaN    NaN
# 3  Australia  2013  2013  152.7        NaN    NaN
# 4  Australia  2014  2014  158.2        NaN    NaN

# %%
Cancer = pd.read_csv("../data/Cancer.csv")
Cancer.head()
# Out:
#         VAR                      Variable      UNIT  \
# 0  CANCTOCA           Malignant neoplasms  PERCMTTX
# 1  CANCTOCA           Malignant neoplasms  PERCMTTX
# 2  CANCTOCA           Malignant neoplasms  PERCMTTX
# 3  CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 4  CANCCOLC  Malignant neoplasms of colon  PERCMTTX
#
#                             Measure  COU    Country   YEA  Year  Value  \
# 0  Incidence per 100 000 population  AUS  Australia  2002  2002  312.0
# 1  Incidence per 100 000 population  AUS  Australia  2008  2008  314.1
# 2  Incidence per 100 000 population  AUS  Australia  2012  2012  323.0
# 3  Incidence per 100 000 population  AUS  Australia  2002  2002   41.7
# 4  Incidence per 100 000 population  AUS  Australia  2008  2008   38.7
#
#    Flag Codes  Flags
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN

# %%
vaping = pd.read_csv("../data/vaping_2012_2022.csv")
vaping.head()
# Out:
#   STRUCTURE                                       STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 1  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 2  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 3  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 4  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
#
#            STRUCTURE_NAME ACTION REF_AREA Reference area FREQ  \
# 0  Use of vaping products      I      CHL          Chile    A
# 1  Use of vaping products      I      CHL          Chile    A
# 2  Use of vaping products      I      CHL          Chile    A
# 3  Use of vaping products      I      CHL          Chile    A
# 4  Use of vaping products      I      SVN       Slovenia    A
#
#   Frequency of observation  MEASURE  \
# 0                   Annual  SP_RVPU
# 1                   Annual  SP_RVPU
# 2                   Annual  SP_RVPU
# 3                   Annual  SP_RVPU
# ...

# %%
Healthcare_coverage = pd.read_csv("../data/Healthcare_coverage_1960_2022.csv")
Healthcare_coverage
# Out:
#       STRUCTURE                                     STRUCTURE_ID  \
# 0      DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 1      DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 2      DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 3      DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 4      DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# ...         ...                                              ...
# 10947  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 10948  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 10949  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 10950  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 10951  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
#
#             STRUCTURE_NAME ACTION REF_AREA Reference area FREQ  \
# 0      Healthcare coverage      I      NLD    Netherlands    A
# ...

# %%
Total_populations = pd.read_csv("../data/Total_populations.csv")
Total_populations.head()
# Out:
#      Country Gender    Age  Year     Value
# 0  Australia  Total  Total  2012  22733465
# 1  Australia  Total  Total  2013  23128129
# 2  Australia  Total  Total  2014  23475686
# 3  Australia  Total  Total  2015  23815995
# 4  Australia  Total  Total  2016  24190907

# %% [markdown]
# # isolate years from 2012-2020

# %%
years_to_keep = list(range(2012, 2021))  #2012 to 2020 [YES]
Healthcare_coverage = Healthcare_coverage[Healthcare_coverage['TIME_PERIOD'].isin(years_to_keep)]
Healthcare_coverage.TIME_PERIOD.value_counts()
Healthcare_coverage.reset_index(drop= True)
#went form 10952 rows down to 2757
# Out:
#      STRUCTURE                                     STRUCTURE_ID  \
# 0     DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 1     DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 2     DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 3     DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 4     DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# ...        ...                                              ...
# 3109  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 3110  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 3111  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 3112  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 3113  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
#
#            STRUCTURE_NAME ACTION REF_AREA Reference area FREQ  \
# 0     Healthcare coverage      I      NLD    Netherlands    A
# 1     Healthcare coverage      I      NLD    Netherlands    A
# ...

# %%
Health_Status.Year.value_counts() #2012-2022
years_to_keep = list(range(2012, 2021))  #2012 to 2020 [YES]
Health_Status = Health_Status[Health_Status['Year'].isin(years_to_keep)]
Health_Status.reset_index(drop= True)
# Out:
#              VAR                              Variable      UNIT  \
# 0       INJRACIR    Injuries in road traffic accidents  BLESSETX
# 1       INJRACIR    Injuries in road traffic accidents  BLESSETX
# 2       INJRACIR    Injuries in road traffic accidents  BLESSETX
# 3       INJRACIR    Injuries in road traffic accidents  BLESSETX
# 4       INJRACIR    Injuries in road traffic accidents  BLESSETX
# ...          ...                                   ...       ...
# 253120  PLYLCVID  Codes for special purposes: COVID-19  ANNTOTTX
# 253121  CICDCVID  Codes for special purposes: COVID-19  TXCMHOTH
# 253122  CICDCVID  Codes for special purposes: COVID-19  TXCMILTX
# 253123  PLYLCVID  Codes for special purposes: COVID-19  ANNHOMTH
# 253124  CICDCVID  Codes for special purposes: COVID-19  NBMALEPH
#
#                                                   Measure  COU    Country  \
# 0                          Injured per million population  AUS  Australia
# ...

# %%
Determinants_of_health.Year.value_counts() #2010-2022
years_to_keep = list(range(2012, 2021))  #2012 to 2020 [YES]
Determinants_of_health = Determinants_of_health[Determinants_of_health['Year'].isin(years_to_keep)]
Determinants_of_health.reset_index(drop= True)
# Out:
#            VAR                                       Variable      UNIT  \
# 0     FOODTFAT                               Total fat supply  PROPERQT
# 1     FOODTFAT                               Total fat supply  PROPERQT
# 2     FOODTFAT                               Total fat supply  PROPERQT
# 3     FOODTFAT                               Total fat supply  PROPERQT
# 4     FOODTFAT                               Total fat supply  PROPERQT
# ...        ...                                            ...       ...
# 8189  FOODVEGE         Vegetables consumption, daily (survey)  FRVGFMTF
# 8190  BODYVBSR  Overweight or obese population, self-reported  PERMANTH
# 8191  BODYVBSR  Overweight or obese population, self-reported  PERMANTH
# 8192  BODYVBSR  Overweight or obese population, self-reported  TOTPOPTX
# 8193  BODYVBSR  Overweight or obese population, self-reported  TOTPOPTX
#
#                                       Measure  COU    Country   YEA  Year  \
# ...

# %%
vaping.TIME_PERIOD.value_counts() #2012-2021
years_to_keep = list(range(2012, 2021))  #2012 to 2020 [YES]
vaping = vaping[vaping['TIME_PERIOD'].isin(years_to_keep)]
vaping.reset_index(drop= True)
# Out:
#     STRUCTURE                                       STRUCTURE_ID  \
# 0    DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 1    DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 2    DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 3    DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 4    DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# ..        ...                                                ...
# 562  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 563  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 564  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 565  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
# 566  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_LVNG@DF_HEALTH_LVNG_VP(...
#
#              STRUCTURE_NAME ACTION REF_AREA Reference area FREQ  \
# 0    Use of vaping products      I      CHL          Chile    A
# ...

# %%
Cancer.Year.value_counts() #2012-2021
years_to_keep = list(range(2012, 2021))  #2012 to 2020 [YES]
Cancer = Cancer[Cancer['Year'].isin(years_to_keep)]
Cancer.reset_index(drop= True)
# Out:
#           VAR                         Variable      UNIT  \
# 0    CANCTOCA              Malignant neoplasms  PERCMTTX
# 1    CANCCOLC     Malignant neoplasms of colon  PERCMTTX
# 2    CANCLUNC      Malignant neoplasms of lung  PERCMTTX
# 3    CANCTOCA              Malignant neoplasms  PERCMTTX
# 4    CANCCOLC     Malignant neoplasms of colon  PERCMTTX
# ..        ...                              ...       ...
# 523  CANCCEIX    Malignant neoplasms of cervix  INCITFTF
# 524  CANCPROC  Malignant neoplasms of prostate  INCITHTH
# 525  CANCLUNC      Malignant neoplasms of lung  PERCMTTX
# 526  CANCCOLC     Malignant neoplasms of colon  INCITFTF
# 527  CANCLUNC      Malignant neoplasms of lung  INCITHTH
#
#                               Measure  COU     Country   YEA  Year  Value  \
# 0    Incidence per 100 000 population  AUS   Australia  2012  2012  323.0
# 1    Incidence per 100 000 population  AUS   Australia  2012  2012   38.4
# ...

# %%
Healthcare_coverage.head()
# Out:
#    STRUCTURE                                     STRUCTURE_ID  \
# 52  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 53  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 54  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 55  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 56  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
#
#          STRUCTURE_NAME ACTION REF_AREA Reference area FREQ  \
# 52  Healthcare coverage      I      NLD    Netherlands    A
# 53  Healthcare coverage      I      NLD    Netherlands    A
# 54  Healthcare coverage      I      NLD    Netherlands    A
# 55  Healthcare coverage      I      NLD    Netherlands    A
# 56  Healthcare coverage      I      NLD    Netherlands    A
#
#    Frequency of observation MEASURE                    Measure  ...  \
# 52                   Annual     HIC  Health insurance coverage  ...
# 53                   Annual     HIC  Health insurance coverage  ...
# ...

# %%
Healthcare_coverage['Frequency of observation'].value_counts()
# Out:
# Frequency of observation
# Annual    3114
# Name: count, dtype: int64

# %% [markdown]
# # Cleaning Healthcare_coverage_clean

# %%
Healthcare_coverage_clean = Healthcare_coverage.drop(columns = ['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA', 'FREQ', 'MEASURE', 'Time period', 'Observation value', 'OBS_STATUS', 'DECIMALS', 'Decimals'])
Healthcare_coverage_clean.reset_index(drop= True)
# Out:
#      Reference area Frequency of observation                    Measure  \
# 0       Netherlands                   Annual  Health insurance coverage
# 1       Netherlands                   Annual  Health insurance coverage
# 2       Netherlands                   Annual  Health insurance coverage
# 3       Netherlands                   Annual  Health insurance coverage
# 4       Netherlands                   Annual  Health insurance coverage
# ...             ...                      ...                        ...
# 3109        Romania                   Annual  Health insurance coverage
# 3110        Romania                   Annual  Health insurance coverage
# 3111        Romania                   Annual  Health insurance coverage
# 3112        Romania                   Annual  Health insurance coverage
# 3113        Romania                   Annual  Health insurance coverage
#
#      UNIT_MEASURE           Unit of measure INSURANCE_TYPE  \
# ...

# %%
Healthcare_coverage_clean = Healthcare_coverage_clean.rename(columns = {'Reference area': 'Country', 'Frequency of observation': 'Annual Insurance', 'TIME_PERIOD': 'Year',})
Healthcare_coverage_clean.reset_index(drop= True)
# Out:
#           Country Annual Insurance                    Measure UNIT_MEASURE  \
# 0     Netherlands           Annual  Health insurance coverage       PT_POP
# 1     Netherlands           Annual  Health insurance coverage       PT_POP
# 2     Netherlands           Annual  Health insurance coverage       PT_POP
# 3     Netherlands           Annual  Health insurance coverage       PT_POP
# 4     Netherlands           Annual  Health insurance coverage       PT_POP
# ...           ...              ...                        ...          ...
# 3109      Romania           Annual  Health insurance coverage           PS
# 3110      Romania           Annual  Health insurance coverage           PS
# 3111      Romania           Annual  Health insurance coverage           PS
# 3112      Romania           Annual  Health insurance coverage           PS
# 3113      Romania           Annual  Health insurance coverage           PS
#
#                Unit of measure INSURANCE_TYPE  \
# ...

# %%
#Government/compulsory health insurance IS A GOVERNMENT THAT REQUIRES HEALTH INSURANCE BY ALL CIVILIANS
#Total voluntary health insurance IS PRIMARY INSURANCE
#Complementary voluntary health insurance IS SECONDARY INSURANCE
#Primary voluntary health insurance IS PRIMARY INSURANCE
#Duplicate voluntary health insurance IS SECONDARY INSURANCE
#Supplementary voluntary health insurance IS SECONDARY INSURANCE
#Public and primary voluntary health insurance IS GOVERNMENT SUBSIDIZED

# %%
Healthcare_coverage_clean['Insurance type'] = Healthcare_coverage_clean['Insurance type'].replace({
    'Government/compulsory health insurance': 'Government Primary',
    'Total voluntary health insurance': 'Primary',
    'Complementary voluntary health insurance': 'Secondary',
    'Primary voluntary health insurance': 'Primary',
    'Duplicate voluntary health insurance': 'Secondary',
    'Supplementary voluntary health insurance': 'Secondary',
    'Public and primary voluntary health insurance': 'Government Secondary'
})
Healthcare_coverage_clean.reset_index(drop= True)
# Out:
#           Country Annual Insurance                    Measure UNIT_MEASURE  \
# 0     Netherlands           Annual  Health insurance coverage       PT_POP
# 1     Netherlands           Annual  Health insurance coverage       PT_POP
# 2     Netherlands           Annual  Health insurance coverage       PT_POP
# 3     Netherlands           Annual  Health insurance coverage       PT_POP
# 4     Netherlands           Annual  Health insurance coverage       PT_POP
# ...           ...              ...                        ...          ...
# 3109      Romania           Annual  Health insurance coverage           PS
# 3110      Romania           Annual  Health insurance coverage           PS
# 3111      Romania           Annual  Health insurance coverage           PS
# 3112      Romania           Annual  Health insurance coverage           PS
# 3113      Romania           Annual  Health insurance coverage           PS
#
# ...

# %%
US_Healthcare_coverage = Healthcare_coverage_clean.loc[Healthcare_coverage_clean.Country == 'United States']
US_Healthcare_coverage.reset_index(drop = True)
# Out:
#           Country Annual Insurance                    Measure UNIT_MEASURE  \
# 0   United States           Annual  Health insurance coverage           PS
# 1   United States           Annual  Health insurance coverage           PS
# 2   United States           Annual  Health insurance coverage           PS
# 3   United States           Annual  Health insurance coverage           PS
# 4   United States           Annual  Health insurance coverage           PS
# ..            ...              ...                        ...          ...
# 76  United States           Annual  Health insurance coverage           PS
# 77  United States           Annual  Health insurance coverage           PS
# 78  United States           Annual  Health insurance coverage           PS
# 79  United States           Annual  Health insurance coverage           PS
# 80  United States           Annual  Health insurance coverage           PS
#
#    Unit of measure INSURANCE_TYPE Insurance type  Year  OBS_VALUE  \
# ...

# %%
US_Healthcare_coverage['Insurance type'].value_counts()
# Out:
# Insurance type
# Primary                 36
# Secondary               18
# Government Primary      18
# Government Secondary     9
# Name: count, dtype: int64

# %%
Healthcare_coverage_clean['Insurance type'].value_counts()
# Out:
# Insurance type
# Secondary               1173
# Primary                  927
# Government Primary       674
# Government Secondary     340
# Name: count, dtype: int64

# %%
Healthcare_coverage_clean['Unit multiplier'].value_counts()
# Out:
# Unit multiplier
# Units        1755
# Thousands    1359
# Name: count, dtype: int64

# %%
Healthcare_coverage_clean['Unit of measure'].value_counts()
# Out:
# Unit of measure
# Percentage of population    1755
# Persons                     1359
# Name: count, dtype: int64

# %%
vaping_clean = vaping.drop(columns = ['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA', 'FREQ', 'MEASURE',
                                     'AGE', 'SEX', 'UNIT_MEASURE', 'METHODOLOGY', 'Measurement method', 'Time period',
                                     'Observation value', 'UNIT_MULT', 'Unit multiplier', 'DECIMALS', 'Decimals'])
vaping_clean.head()
# Out:
#   Reference area Frequency of observation  \
# 0          Chile                   Annual
# 1          Chile                   Annual
# 2          Chile                   Annual
# 3          Chile                   Annual
# 4       Slovenia                   Annual
#
#                                              Measure               Age    Sex  \
# 0  Share of population who are regular vaping pro...  15 years or over  Total
# 1  Share of population who are regular vaping pro...  15 years or over  Total
# 2  Share of population who are regular vaping pro...  15 years or over  Total
# 3  Share of population who are regular vaping pro...  15 years or over  Total
# 4  Share of population who are regular vaping pro...  15 years or over   Male
#
#             Unit of measure  TIME_PERIOD  OBS_VALUE OBS_STATUS  \
# 0  Percentage of population         2014        1.0          D
# 1  Percentage of population         2016        1.2          D
# ...

# %%
vaping_clean = vaping_clean.rename(columns = {'Reference area': 'Country', 'TIME_PERIOD': 'Year', 'OBS_VALUE': 'Percent'})
vaping_clean.head()
# Out:
#     Country Frequency of observation  \
# 0     Chile                   Annual
# 1     Chile                   Annual
# 2     Chile                   Annual
# 3     Chile                   Annual
# 4  Slovenia                   Annual
#
#                                              Measure               Age    Sex  \
# 0  Share of population who are regular vaping pro...  15 years or over  Total
# 1  Share of population who are regular vaping pro...  15 years or over  Total
# 2  Share of population who are regular vaping pro...  15 years or over  Total
# 3  Share of population who are regular vaping pro...  15 years or over  Total
# 4  Share of population who are regular vaping pro...  15 years or over   Male
#
#             Unit of measure  Year  Percent OBS_STATUS  Observation status
# 0  Percentage of population  2014      1.0          D  Definition differs
# 1  Percentage of population  2016      1.2          D  Definition differs
# ...

# %%
Cancer
# Out:
#            VAR                         Variable      UNIT  \
# 2     CANCTOCA              Malignant neoplasms  PERCMTTX
# 5     CANCCOLC     Malignant neoplasms of colon  PERCMTTX
# 8     CANCLUNC      Malignant neoplasms of lung  PERCMTTX
# 12    CANCTOCA              Malignant neoplasms  PERCMTTX
# 16    CANCCOLC     Malignant neoplasms of colon  PERCMTTX
# ...        ...                              ...       ...
# 1483  CANCCEIX    Malignant neoplasms of cervix  INCITFTF
# 1484  CANCPROC  Malignant neoplasms of prostate  INCITHTH
# 1485  CANCLUNC      Malignant neoplasms of lung  PERCMTTX
# 1486  CANCCOLC     Malignant neoplasms of colon  INCITFTF
# 1487  CANCLUNC      Malignant neoplasms of lung  INCITHTH
#
#                                Measure  COU     Country   YEA  Year  Value  \
# 2     Incidence per 100 000 population  AUS   Australia  2012  2012  323.0
# 5     Incidence per 100 000 population  AUS   Australia  2012  2012   38.4
# ...

# %%
cancer_clean = Cancer.drop(columns = ['VAR', 'UNIT', 'COU', 'YEA', 'Flag Codes', 'Flags'])
cancer_clean.reset_index(drop = True)
# Out:
#                             Variable                           Measure  \
# 0                Malignant neoplasms  Incidence per 100 000 population
# 1       Malignant neoplasms of colon  Incidence per 100 000 population
# 2        Malignant neoplasms of lung  Incidence per 100 000 population
# 3                Malignant neoplasms  Incidence per 100 000 population
# 4       Malignant neoplasms of colon  Incidence per 100 000 population
# ..                               ...                               ...
# 523    Malignant neoplasms of cervix     Incidence per 100 000 females
# 524  Malignant neoplasms of prostate       Incidence per 100 000 males
# 525      Malignant neoplasms of lung  Incidence per 100 000 population
# 526     Malignant neoplasms of colon     Incidence per 100 000 females
# 527      Malignant neoplasms of lung       Incidence per 100 000 males
#
#         Country  Year  Value
# 0     Australia  2012  323.0
# 1     Australia  2012   38.4
# ...

# %%
Determinants_of_health_clean = Determinants_of_health.drop(columns = ['VAR', 'UNIT', 'COU', 'YEA', 'Flag Codes', 'Flags'])
Determinants_of_health_clean.reset_index(drop = True)
# Out:
#                                            Variable  \
# 0                                  Total fat supply
# 1                                  Total fat supply
# 2                                  Total fat supply
# 3                                  Total fat supply
# 4                                  Total fat supply
# ...                                             ...
# 8189         Vegetables consumption, daily (survey)
# 8190  Overweight or obese population, self-reported
# 8191  Overweight or obese population, self-reported
# 8192  Overweight or obese population, self-reported
# 8193  Overweight or obese population, self-reported
#
#                                       Measure    Country  Year  Value
# 0                    Grams per capita per day  Australia  2012  156.4
# 1                    Grams per capita per day  Australia  2013  152.7
# 2                    Grams per capita per day  Australia  2014  158.2
# ...

# %%
Health_Status_clean = Health_Status.drop(columns = ['VAR','UNIT', 'COU', 'YEA', 'Flag Codes', 'Flags'])
Health_Status_clean.reset_index(drop= True)
# Out:
#                                     Variable  \
# 0         Injuries in road traffic accidents
# 1         Injuries in road traffic accidents
# 2         Injuries in road traffic accidents
# 3         Injuries in road traffic accidents
# 4         Injuries in road traffic accidents
# ...                                      ...
# 253120  Codes for special purposes: COVID-19
# 253121  Codes for special purposes: COVID-19
# 253122  Codes for special purposes: COVID-19
# 253123  Codes for special purposes: COVID-19
# 253124  Codes for special purposes: COVID-19
#
#                                                   Measure    Country  Year  \
# 0                          Injured per million population  Australia  2012
# 1                          Injured per million population  Australia  2013
# 2                          Injured per million population  Australia  2014
# 3                          Injured per million population  Australia  2015
# ...

# %%
Health_Status_clean.Country.value_counts()
# Out:
# Country
# United States                   6171
# Spain                           6167
# Austria                         6167
# Netherlands                     6159
# Poland                          6158
# Czechia                         6158
# Latvia                          6156
# Denmark                         6153
# Israel                          6153
# Switzerland                     6150
# Estonia                         6146
# Germany                         6138
# Lithuania                       6133
# United Kingdom                  6127
# Bulgaria                        6090
# Greece                          6056
# Korea                           6030
# Slovenia                        5979
# Chile                           5973
# Japan                           5961
# Luxembourg                      5923
# Colombia                        5906
# Australia                       5900
# Costa Rica                      5864
# Mexico                          5847
# ...

# %%
US_Health_Status = Health_Status_clean.loc[Health_Status_clean.Country == 'United States'].reset_index(drop= True)
US_Health_Status
# Out:
#                                   Variable  \
# 0       Injuries in road traffic accidents
# 1       Injuries in road traffic accidents
# 2       Injuries in road traffic accidents
# 3       Injuries in road traffic accidents
# 4       Injuries in road traffic accidents
# ...                                    ...
# 6166  Codes for special purposes: COVID-19
# 6167  Codes for special purposes: COVID-19
# 6168  Codes for special purposes: COVID-19
# 6169  Codes for special purposes: COVID-19
# 6170  Codes for special purposes: COVID-19
#
#                                               Measure        Country  Year  \
# 0                      Injured per million population  United States  2012
# 1                      Injured per million population  United States  2013
# 2                      Injured per million population  United States  2014
# 3                      Injured per million population  United States  2015
# ...

# %%
#Healthcare_coverage_clean

#US_Healthcare_coverage

#vaping_clean

#cancer_clean

#Determinants_of_health_clean

#Health_Status_clean

#US_Health_Status

#Health_Status_Cancer

#Total_populations

#Total_Lung_CA_pop (percent of people who died by Lung CA)

#Daily_Smokers (percent of daily smokers over age 15)

# %%
Health_Status_Cancer = Health_Status_clean[Health_Status_clean['Variable'].str.contains('malignant', na = False, case = False)].reset_index(drop= True)
Health_Status_Cancer
# Out:
#                               Variable  \
# 0                  Malignant neoplasms
# 1                  Malignant neoplasms
# 2                  Malignant neoplasms
# 3                  Malignant neoplasms
# 4                  Malignant neoplasms
# ...                                ...
# 42523  Malignant neoplasms of prostate
# 42524  Malignant neoplasms of prostate
# 42525  Malignant neoplasms of prostate
# 42526  Malignant neoplasms of prostate
# 42527  Malignant neoplasms of prostate
#
#                                                  Measure    Country  Year  \
# 0      Deaths per 100 000 population (standardised ra...  Australia  2012
# 1      Deaths per 100 000 population (standardised ra...  Australia  2013
# 2      Deaths per 100 000 population (standardised ra...  Australia  2014
# 3      Deaths per 100 000 population (standardised ra...  Australia  2015
# 4      Deaths per 100 000 population (standardised ra...  Australia  2016
# ...

# %%
Health_Status_Cancer.Variable.value_counts()
# Out:
# Variable
# Malignant neoplasms                               4632
# Malignant neoplasms of colon, rectum and anus     4500
# Malignant neoplasms of trachea, bronchus, lung    4500
# Malignant neoplasms of stomach                    4500
# Malignant neoplasms of pancreas                   4500
# Malignant neoplasms of liver                      4500
# Malignant neoplasms of bladder                    4500
# Malignant melanoma of skin                        4500
# Malignant neoplasms of female breast              1544
# Malignant neoplasms of prostate                   1544
# Malignant neoplasms of cervix uteri               1500
# Malignant neoplasms of ovary                      1500
# Malignant neoplasms of colon                       132
# Malignant neoplasms of lung                        132
# Malignant neoplasms of cervix                       44
# Name: count, dtype: int64

# %%
#might not use. Health_Status_Clean is better
cancer_clean
# Out:
#                              Variable                           Measure  \
# 2                 Malignant neoplasms  Incidence per 100 000 population
# 5        Malignant neoplasms of colon  Incidence per 100 000 population
# 8         Malignant neoplasms of lung  Incidence per 100 000 population
# 12                Malignant neoplasms  Incidence per 100 000 population
# 16       Malignant neoplasms of colon  Incidence per 100 000 population
# ...                               ...                               ...
# 1483    Malignant neoplasms of cervix     Incidence per 100 000 females
# 1484  Malignant neoplasms of prostate       Incidence per 100 000 males
# 1485      Malignant neoplasms of lung  Incidence per 100 000 population
# 1486     Malignant neoplasms of colon     Incidence per 100 000 females
# 1487      Malignant neoplasms of lung       Incidence per 100 000 males
#
#          Country  Year  Value
# 2      Australia  2012  323.0
# 5      Australia  2012   38.4
# ...

# %%
Health_Status_clean.head()
# Out:
#                              Variable                         Measure  \
# 2  Injuries in road traffic accidents  Injured per million population
# 3  Injuries in road traffic accidents  Injured per million population
# 4  Injuries in road traffic accidents  Injured per million population
# 5  Injuries in road traffic accidents  Injured per million population
# 6  Injuries in road traffic accidents  Injured per million population
#
#      Country  Year   Value
# 2  Australia  2012  1486.9
# 3  Australia  2013  1504.8
# 4  Australia  2014  1503.9
# 5  Australia  2015  1546.1
# 6  Australia  2016  1596.8

# %% [markdown]
# # To correlate

# %% [markdown]
# # 1a) Let's correlate Lung CA with smoking dataset

# %%
Lung_CA = Health_Status_Cancer.loc[Health_Status_Cancer.Variable == "Malignant neoplasms of trachea, bronchus, lung"]
Lung_CA.reset_index(drop= True)
#schools.loc[schools.level == "Middle School"]
# Out:
#                                             Variable  \
# 0     Malignant neoplasms of trachea, bronchus, lung
# 1     Malignant neoplasms of trachea, bronchus, lung
# 2     Malignant neoplasms of trachea, bronchus, lung
# 3     Malignant neoplasms of trachea, bronchus, lung
# 4     Malignant neoplasms of trachea, bronchus, lung
# ...                                              ...
# 4495  Malignant neoplasms of trachea, bronchus, lung
# 4496  Malignant neoplasms of trachea, bronchus, lung
# 4497  Malignant neoplasms of trachea, bronchus, lung
# 4498  Malignant neoplasms of trachea, bronchus, lung
# 4499  Malignant neoplasms of trachea, bronchus, lung
#
#                                                 Measure    Country  Year  \
# 0     Deaths per 100 000 population (standardised ra...  Australia  2012
# 1     Deaths per 100 000 population (standardised ra...  Australia  2013
# 2     Deaths per 100 000 population (standardised ra...  Australia  2014
# ...

# %%
Health_Status_Cancer.Variable.value_counts()
# Out:
# Variable
# Malignant neoplasms                               4632
# Malignant neoplasms of colon, rectum and anus     4500
# Malignant neoplasms of trachea, bronchus, lung    4500
# Malignant neoplasms of stomach                    4500
# Malignant neoplasms of pancreas                   4500
# Malignant neoplasms of liver                      4500
# Malignant neoplasms of bladder                    4500
# Malignant melanoma of skin                        4500
# Malignant neoplasms of female breast              1544
# Malignant neoplasms of prostate                   1544
# Malignant neoplasms of cervix uteri               1500
# Malignant neoplasms of ovary                      1500
# Malignant neoplasms of colon                       132
# Malignant neoplasms of lung                        132
# Malignant neoplasms of cervix                       44
# Name: count, dtype: int64

# %%
type(Lung_CA)
# Out:
# pandas.core.frame.DataFrame

# %%
Lung_CA['Variable'] = Lung_CA['Variable'].replace({'Malignant neoplasms of trachea, bronchus, lung': 'Lung Cancer'})
Lung_CA.reset_index(drop= True)
# Out:
# C:\Users\derek\AppData\Local\Temp\ipykernel_37692\2687613059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Lung_CA['Variable'] = Lung_CA['Variable'].replace({'Malignant neoplasms of trachea, bronchus, lung': 'Lung Cancer'})
#          Variable                                            Measure  \
# 0     Lung Cancer  Deaths per 100 000 population (standardised ra...
# 1     Lung Cancer  Deaths per 100 000 population (standardised ra...
# 2     Lung Cancer  Deaths per 100 000 population (standardised ra...
# 3     Lung Cancer  Deaths per 100 000 population (standardised ra...
# 4     Lung Cancer  Deaths per 100 000 population (standardised ra...
# ...           ...                                                ...
# ...

# %%
Lung_CA.Variable.value_counts()
# Out:
# Variable
# Lung Cancer    4500
# Name: count, dtype: int64

# %%
Lung_CA.Year.unique() #48 countries, 9 years
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
Lung_CA.Measure.value_counts()
# Out:
# Measure
# Deaths per 100 000 population (standardised rates)    375
# Deaths per 100 000 females (standardised rates)       375
# Deaths per 100 000 males (standardised rates)         375
# Years lost, /100 000 males, aged 75 years old         375
# Years lost, /100 000 females, aged 75 years old       375
# Years lost, /100 000 population, aged 75 years old    375
# Number of female deaths                               375
# Number of male deaths                                 375
# Number of total deaths                                375
# Deaths per 100 000 males (crude rates)                375
# Deaths per 100 000 population (crude rates)           375
# Deaths per 100 000 females (crude rates)              375
# Name: count, dtype: int64

# %%
Total_Lung_CA_deaths = Lung_CA.loc[Lung_CA.Measure == "Number of total deaths"]
Total_Lung_CA_deaths.reset_index(drop=True)
Total_Lung_CA_deaths
#Health_Status_Cancer.loc[Health_Status_Cancer.Variable == "Malignant neoplasms of trachea, bronchus, lung"]
# Out:
#           Variable                 Measure    Country  Year   Value
# 22994  Lung Cancer  Number of total deaths  Australia  2012  8138.0
# 22995  Lung Cancer  Number of total deaths  Australia  2013  8215.0
# 22996  Lung Cancer  Number of total deaths  Australia  2014  8252.0
# 22997  Lung Cancer  Number of total deaths  Australia  2015  8470.0
# 22998  Lung Cancer  Number of total deaths  Australia  2016  8411.0
# ...            ...                     ...        ...   ...     ...
# 41317  Lung Cancer  Number of total deaths    Croatia  2015  2821.0
# 41318  Lung Cancer  Number of total deaths    Croatia  2016  2866.0
# 41319  Lung Cancer  Number of total deaths    Croatia  2017  2994.0
# 41320  Lung Cancer  Number of total deaths    Croatia  2019  2874.0
# 41321  Lung Cancer  Number of total deaths    Croatia  2020  2819.0
#
# [375 rows x 5 columns]

# %%
Total_populations
# Out:
#        Country Gender    Age  Year     Value
# 0    Australia  Total  Total  2012  22733465
# 1    Australia  Total  Total  2013  23128129
# 2    Australia  Total  Total  2014  23475686
# 3    Australia  Total  Total  2015  23815995
# 4    Australia  Total  Total  2016  24190907
# ..         ...    ...    ...   ...       ...
# 436    Croatia  Total  Total  2016   4223751
# 437    Croatia  Total  Total  2017   4192467
# 438    Croatia  Total  Total  2018   4160485
# 439    Croatia  Total  Total  2019   4129752
# 440    Croatia  Total  Total  2020   4096869
#
# [441 rows x 5 columns]

# %%
Total_Lung_CA_pop = pd.merge(Total_Lung_CA_deaths, Total_populations, on = ['Country', 'Year'], how = 'inner')
Total_Lung_CA_pop = Total_Lung_CA_pop.drop(columns = ['Gender', 'Age'])
Total_Lung_CA_pop = Total_Lung_CA_pop.rename(columns = {'Value_x': 'Deaths', 'Value_y': 'Population'})
Total_Lung_CA_pop['Total Deaths Percent'] = Total_Lung_CA_pop['Deaths']/ Total_Lung_CA_pop['Population']*100
Total_Lung_CA_pop
# Out:
#         Variable                 Measure    Country  Year  Deaths  Population  \
# 0    Lung Cancer  Number of total deaths  Australia  2012  8138.0    22733465
# 1    Lung Cancer  Number of total deaths  Australia  2013  8215.0    23128129
# 2    Lung Cancer  Number of total deaths  Australia  2014  8252.0    23475686
# 3    Lung Cancer  Number of total deaths  Australia  2015  8470.0    23815995
# 4    Lung Cancer  Number of total deaths  Australia  2016  8411.0    24190907
# ..           ...                     ...        ...   ...     ...         ...
# 370  Lung Cancer  Number of total deaths    Croatia  2015  2821.0     4254815
# 371  Lung Cancer  Number of total deaths    Croatia  2016  2866.0     4223751
# 372  Lung Cancer  Number of total deaths    Croatia  2017  2994.0     4192467
# 373  Lung Cancer  Number of total deaths    Croatia  2019  2874.0     4129752
# 374  Lung Cancer  Number of total deaths    Croatia  2020  2819.0     4096869
#
#      Total Deaths Percent
# ...

# %%
type(Total_Lung_CA_pop)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Lung CA Deaths table

# %%
pivot_df = Total_Lung_CA_deaths.pivot_table(index='Country', columns='Year', values='Value')

plt.figure(figsize=(12, 10))
sns.heatmap(pivot_df, cmap='YlGnBu', annot=True, fmt=".1f", linewidths=.5)
plt.title('Lung Cancer Deaths by Year')
plt.xlabel('Year')
plt.ylabel('Country')
plt.show();

# %%
pivot_df = Total_Lung_CA_pop.pivot_table(index='Country', columns='Year', values='Total Deaths Percent')

plt.figure(figsize=(12, 10))
sns.heatmap(pivot_df, cmap='YlGnBu', annot=True, fmt=".5f", linewidths=.5)
plt.title('Lung Cancer % of Deaths')
plt.xlabel('Year')
plt.ylabel('Country')
plt.show();

# %%
type(Total_Lung_CA_deaths)
# Out:
# pandas.core.frame.DataFrame

# %%
Total_Lung_CA_deaths.describe()
# Out:
#               Year          Value
# count   375.000000     375.000000
# mean   2015.730667   14767.496000
# std       2.525695   25967.594358
# min    2012.000000     117.000000
# 25%    2014.000000    2165.500000
# 50%    2016.000000    4797.000000
# 75%    2018.000000   19159.000000
# max    2020.000000  157499.000000

# %%
Lung_CA_deaths_average = Total_Lung_CA_deaths.groupby(['Country'])['Value'].mean().sort_values(ascending=False)
Lung_CA_deaths_average = Lung_CA_deaths_average.to_frame().reset_index()
Lung_CA_deaths_average.head()
# Out:
#           Country          Value
# 0   United States  148451.777778
# 1           Japan   73921.222222
# 2          Russia   50206.400000
# 3         Germany   45012.222222
# 4  United Kingdom   35121.888889

# %%
type(Lung_CA_deaths_average)
# Out:
# pandas.core.frame.DataFrame

# %%
Lung_CA_deaths_sum = Total_Lung_CA_deaths.groupby(['Country'])['Value'].sum().sort_values(ascending=False)
Lung_CA_deaths_sum = Lung_CA_deaths_sum.to_frame().reset_index()
Lung_CA_deaths_sum.head()
# Out:
#           Country      Value
# 0   United States  1336066.0
# 1           Japan   665291.0
# 2         Germany   405110.0
# 3  United Kingdom   316097.0
# 4          Russia   251032.0

# %% [markdown]
# plt.figure(figsize = (10,6))
#
# sns.scatterplot(data = Total_Lung_CA_deaths,
#                x = 'Year',
#                y = 'Value',
#                hue = 'Country',
#                palette = 'colorblind');

# %%
type(Lung_CA_deaths_sum)
# Out:
# pandas.core.frame.DataFrame

# %%
Lung_CA.Measure.value_counts()
# Out:
# Measure
# Deaths per 100 000 population (standardised rates)    375
# Deaths per 100 000 females (standardised rates)       375
# Deaths per 100 000 males (standardised rates)         375
# Years lost, /100 000 males, aged 75 years old         375
# Years lost, /100 000 females, aged 75 years old       375
# Years lost, /100 000 population, aged 75 years old    375
# Number of female deaths                               375
# Number of male deaths                                 375
# Number of total deaths                                375
# Deaths per 100 000 males (crude rates)                375
# Deaths per 100 000 population (crude rates)           375
# Deaths per 100 000 females (crude rates)              375
# Name: count, dtype: int64

# %%
Lung_CA_deaths_per_100k_pop = Lung_CA.loc[Lung_CA.Measure == "Deaths per 100 000 population (crude rates)"]
Lung_CA_deaths_per_100k_pop = Lung_CA_deaths_per_100k_pop.reset_index(drop=True)
Lung_CA_deaths_per_100k_pop
# Out:
#         Variable                                      Measure    Country  \
# 0    Lung Cancer  Deaths per 100 000 population (crude rates)   Portugal
# 1    Lung Cancer  Deaths per 100 000 population (crude rates)   Portugal
# 2    Lung Cancer  Deaths per 100 000 population (crude rates)   Portugal
# 3    Lung Cancer  Deaths per 100 000 population (crude rates)   Portugal
# 4    Lung Cancer  Deaths per 100 000 population (crude rates)   Portugal
# ..           ...                                          ...        ...
# 370  Lung Cancer  Deaths per 100 000 population (crude rates)  Argentina
# 371  Lung Cancer  Deaths per 100 000 population (crude rates)  Argentina
# 372  Lung Cancer  Deaths per 100 000 population (crude rates)  Argentina
# 373  Lung Cancer  Deaths per 100 000 population (crude rates)  Argentina
# 374  Lung Cancer  Deaths per 100 000 population (crude rates)  Argentina
#
#      Year  Value
# 0    2012   35.0
# 1    2013   38.3
# 2    2014   37.9
# 3    2015   38.8
# ...

# %%
Lung_CA_deaths_per_100k_pop_average = Lung_CA_deaths_per_100k_pop.groupby(['Country'])['Value'].mean().sort_values(ascending=False)
Lung_CA_deaths_per_100k_pop_average = Lung_CA_deaths_per_100k_pop_average.to_frame().reset_index()
Lung_CA_deaths_per_100k_pop_average.head()
# Out:
#    Country      Value
# 0  Hungary  88.787500
# 1  Croatia  68.325000
# 2   Greece  65.155556
# 3  Denmark  63.300000
# 4   Poland  61.011111

# %%
type(Lung_CA_deaths_per_100k_pop)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 1b) Tobacco consumption

# %%
Tobacco_consumption = Determinants_of_health_clean.loc[Determinants_of_health_clean.Variable == "Tobacco consumption"]
Tobacco_consumption.reset_index(drop=True)
# Out:
#                  Variable                                            Measure  \
# 0     Tobacco consumption                             Grams per capita (15+)
# 1     Tobacco consumption                             Grams per capita (15+)
# 2     Tobacco consumption                             Grams per capita (15+)
# 3     Tobacco consumption                             Grams per capita (15+)
# 4     Tobacco consumption                             Grams per capita (15+)
# ...                   ...                                                ...
# 1648  Tobacco consumption                      Cigarettes per smoker per day
# 1649  Tobacco consumption  % of males aged 15-24 years old who are daily ...
# 1650  Tobacco consumption  % of males aged 15-24 years old who are daily ...
# 1651  Tobacco consumption        % of females aged 15+ who are daily smokers
# 1652  Tobacco consumption        % of females aged 15+ who are daily smokers
#
#         Country  Year  Value
# ...

# %%
type(Tobacco_consumption)
# Out:
# pandas.core.frame.DataFrame

# %%
Tobacco_consumption.Measure.value_counts()
# Out:
# Measure
# % of population aged 15+ who are daily smokers                243
# % of females aged 15+ who are daily smokers                   242
# % of males aged 15+ who are daily smokers                     242
# % of population aged 15-24 years old who are daily smokers    192
# % of males aged 15-24 years old who are daily smokers         192
# % of females aged 15-24 years old who are daily smokers       192
# Grams per capita (15+)                                        184
# Cigarettes per smoker per day                                 166
# Name: count, dtype: int64

# %%
Daily_Smokers = Tobacco_consumption.loc[Tobacco_consumption.Measure == '% of population aged 15+ who are daily smokers']
Daily_Smokers = Daily_Smokers.reset_index(drop = True)
Daily_Smokers = Daily_Smokers.rename(columns = {'Value': 'Percent of Smokers'})
Daily_Smokers
# Out:
#                 Variable                                         Measure  \
# 0    Tobacco consumption  % of population aged 15+ who are daily smokers
# 1    Tobacco consumption  % of population aged 15+ who are daily smokers
# 2    Tobacco consumption  % of population aged 15+ who are daily smokers
# 3    Tobacco consumption  % of population aged 15+ who are daily smokers
# 4    Tobacco consumption  % of population aged 15+ who are daily smokers
# ..                   ...                                             ...
# 238  Tobacco consumption  % of population aged 15+ who are daily smokers
# 239  Tobacco consumption  % of population aged 15+ who are daily smokers
# 240  Tobacco consumption  % of population aged 15+ who are daily smokers
# 241  Tobacco consumption  % of population aged 15+ who are daily smokers
# 242  Tobacco consumption  % of population aged 15+ who are daily smokers
#
#        Country  Year  Percent of Smokers
# 0    Australia  2013                13.0
# ...

# %%
type(Daily_Smokers)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Daily Smokers tables

# %%
#Alphabetical Country
pivot_df = Daily_Smokers.pivot_table(index='Country', columns='Year', values='Percent of Smokers')

plt.figure(figsize=(12, 10))
sns.heatmap(pivot_df, cmap='YlGnBu', annot=True, fmt=".1f", linewidths=.5)
plt.title('Percent of Daily Smokers age 15+')
plt.xlabel('Year')
plt.ylabel('Country')
plt.show();

# %%
#Descending
pivot_df = Daily_Smokers.pivot_table(index='Country', columns='Year', values='Percent of Smokers')

pivot_df = pivot_df.sort_values(by=pivot_df.columns[-1], ascending=False)

plt.figure(figsize=(12, 10))
sns.heatmap(pivot_df, cmap='YlGnBu', annot=True, fmt=".1f", linewidths=.5)
plt.title('Percent of Daily Smokers age 15+')
plt.xlabel('Year')
plt.ylabel('Country')
plt.show();

# %% [markdown]
# # Two df's for correlation

# %%
Total_Lung_CA_pop.head()
# Out:
#       Variable                 Measure    Country  Year  Deaths  Population  \
# 0  Lung Cancer  Number of total deaths  Australia  2012  8138.0    22733465
# 1  Lung Cancer  Number of total deaths  Australia  2013  8215.0    23128129
# 2  Lung Cancer  Number of total deaths  Australia  2014  8252.0    23475686
# 3  Lung Cancer  Number of total deaths  Australia  2015  8470.0    23815995
# 4  Lung Cancer  Number of total deaths  Australia  2016  8411.0    24190907
#
#    Total Deaths Percent
# 0              0.035797
# 1              0.035520
# 2              0.035151
# 3              0.035564
# 4              0.034769

# %%
Daily_Smokers.head()
# Out:
#               Variable                                         Measure  \
# 0  Tobacco consumption  % of population aged 15+ who are daily smokers
# 1  Tobacco consumption  % of population aged 15+ who are daily smokers
# 2  Tobacco consumption  % of population aged 15+ who are daily smokers
# 3  Tobacco consumption  % of population aged 15+ who are daily smokers
# 4  Tobacco consumption  % of population aged 15+ who are daily smokers
#
#      Country  Year  Percent of Smokers
# 0  Australia  2013                13.0
# 1  Australia  2016                12.4
# 2  Australia  2019                11.2
# 3    Austria  2014                24.3
# 4    Austria  2019                20.6

# %%
Daily_Smokers.dtypes
# Out:
# Variable               object
# Measure                object
# Country                object
# Year                    int64
# Percent of Smokers    float64
# dtype: object

# %% [markdown]
# # Making lung CA and smoking correlation

# %%
Correlation1 = pd.merge(Total_Lung_CA_pop, Daily_Smokers, on = ['Country', 'Year'], how = 'inner')
Correlation1
# Out:
#       Variable_x               Measure_x    Country  Year   Deaths  \
# 0    Lung Cancer  Number of total deaths  Australia  2013   8215.0
# 1    Lung Cancer  Number of total deaths  Australia  2016   8411.0
# 2    Lung Cancer  Number of total deaths  Australia  2019   8825.0
# 3    Lung Cancer  Number of total deaths    Austria  2014   3908.0
# 4    Lung Cancer  Number of total deaths    Austria  2019   3991.0
# ..           ...                     ...        ...   ...      ...
# 200  Lung Cancer  Number of total deaths       Peru  2020   2099.0
# 201  Lung Cancer  Number of total deaths    Romania  2014  10188.0
# 202  Lung Cancer  Number of total deaths    Romania  2019   9803.0
# 203  Lung Cancer  Number of total deaths    Croatia  2014   2827.0
# 204  Lung Cancer  Number of total deaths    Croatia  2019   2874.0
#
#      Population  Total Deaths Percent           Variable_y  \
# 0      23128129              0.035520  Tobacco consumption
# ...

# %% [markdown]
# # This Data is across 49 countries between the years 2012 - 2020

# %%
Correlation1[['Total Deaths Percent', 'Percent of Smokers']].corr()
# Out:
#                       Total Deaths Percent  Percent of Smokers
# Total Deaths Percent              1.000000            0.438555
# Percent of Smokers                0.438555            1.000000

# %% [markdown]
# # A correlation coefficient of 0.438 indicates a moderate positive relationship between the variables. It suggests a meaningful association but not a perfect one

# %% [markdown]
# # 2a) Let's correlate Liver CA with alcohol consumption

# %%
Liver_CA = Health_Status_Cancer.loc[Health_Status_Cancer.Variable == "Malignant neoplasms of liver"]
Liver_CA.reset_index(drop= True)
# Out:
#                           Variable  \
# 0     Malignant neoplasms of liver
# 1     Malignant neoplasms of liver
# 2     Malignant neoplasms of liver
# 3     Malignant neoplasms of liver
# 4     Malignant neoplasms of liver
# ...                            ...
# 4495  Malignant neoplasms of liver
# 4496  Malignant neoplasms of liver
# 4497  Malignant neoplasms of liver
# 4498  Malignant neoplasms of liver
# 4499  Malignant neoplasms of liver
#
#                                                 Measure    Country  Year  \
# 0     Deaths per 100 000 population (standardised ra...  Australia  2012
# 1     Deaths per 100 000 population (standardised ra...  Australia  2013
# 2     Deaths per 100 000 population (standardised ra...  Australia  2014
# 3     Deaths per 100 000 population (standardised ra...  Australia  2015
# 4     Deaths per 100 000 population (standardised ra...  Australia  2016
# ...                                                 ...        ...   ...
# ...

# %%
Liver_CA['Variable'] = Liver_CA['Variable'].replace({'Malignant neoplasms of liver': 'Liver Cancer'})
Liver_CA.reset_index(drop= True)
# Out:
# C:\Users\derek\AppData\Local\Temp\ipykernel_37692\2196935178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Liver_CA['Variable'] = Liver_CA['Variable'].replace({'Malignant neoplasms of liver': 'Liver Cancer'})
#           Variable                                            Measure  \
# 0     Liver Cancer  Deaths per 100 000 population (standardised ra...
# 1     Liver Cancer  Deaths per 100 000 population (standardised ra...
# 2     Liver Cancer  Deaths per 100 000 population (standardised ra...
# 3     Liver Cancer  Deaths per 100 000 population (standardised ra...
# 4     Liver Cancer  Deaths per 100 000 population (standardised ra...
# ...            ...                                                ...
# ...

# %%
Total_Liver_CA_deaths = Liver_CA.loc[Liver_CA.Measure == "Number of total deaths"]
Total_Liver_CA_deaths = Total_Liver_CA_deaths.reset_index(drop= True)
Total_Liver_CA_deaths
# Out:
#          Variable                 Measure    Country  Year   Value
# 0    Liver Cancer  Number of total deaths  Australia  2012  1490.0
# 1    Liver Cancer  Number of total deaths  Australia  2013  1574.0
# 2    Liver Cancer  Number of total deaths  Australia  2014  1732.0
# 3    Liver Cancer  Number of total deaths  Australia  2015  1820.0
# 4    Liver Cancer  Number of total deaths  Australia  2016  1866.0
# ..            ...                     ...        ...   ...     ...
# 370  Liver Cancer  Number of total deaths  Argentina  2016  1870.0
# 371  Liver Cancer  Number of total deaths  Argentina  2017  1985.0
# 372  Liver Cancer  Number of total deaths  Argentina  2018  1901.0
# 373  Liver Cancer  Number of total deaths  Argentina  2019  1922.0
# 374  Liver Cancer  Number of total deaths  Argentina  2020  2031.0
#
# [375 rows x 5 columns]

# %%
Total_Liver_CA_pop = pd.merge(Total_Liver_CA_deaths, Total_populations, on = ['Country', 'Year'], how = 'inner')
Total_Liver_CA_pop = Total_Liver_CA_pop.drop(columns = ['Gender', 'Age'])
Total_Liver_CA_pop = Total_Liver_CA_pop.rename(columns = {'Value_x': 'Deaths', 'Value_y': 'Population'})
Total_Liver_CA_pop['Total Deaths Percent'] = Total_Liver_CA_pop['Deaths']/ Total_Liver_CA_pop['Population']*100
Total_Liver_CA_pop
# Out:
#          Variable                 Measure    Country  Year  Deaths  \
# 0    Liver Cancer  Number of total deaths  Australia  2012  1490.0
# 1    Liver Cancer  Number of total deaths  Australia  2013  1574.0
# 2    Liver Cancer  Number of total deaths  Australia  2014  1732.0
# 3    Liver Cancer  Number of total deaths  Australia  2015  1820.0
# 4    Liver Cancer  Number of total deaths  Australia  2016  1866.0
# ..            ...                     ...        ...   ...     ...
# 370  Liver Cancer  Number of total deaths  Argentina  2016  1870.0
# 371  Liver Cancer  Number of total deaths  Argentina  2017  1985.0
# 372  Liver Cancer  Number of total deaths  Argentina  2018  1901.0
# 373  Liver Cancer  Number of total deaths  Argentina  2019  1922.0
# 374  Liver Cancer  Number of total deaths  Argentina  2020  2031.0
#
#      Population  Total Deaths Percent
# 0      22733465              0.006554
# 1      23128129              0.006806
# 2      23475686              0.007378
# ...

# %% [markdown]
# # 2b) Alcohol Consumption

# %%
Alcohol_consumption = Determinants_of_health_clean.loc[Determinants_of_health_clean.Variable == "Alcohol consumption"]
Alcohol_consumption = Alcohol_consumption.reset_index(drop=True)
Alcohol_consumption = Alcohol_consumption.rename(columns = {'Value': 'Litres per Person'})
Alcohol_consumption
# Out:
#                 Variable                  Measure    Country  Year  \
# 0    Alcohol consumption  Litres per capita (15+)  Australia  2012
# 1    Alcohol consumption  Litres per capita (15+)  Australia  2013
# 2    Alcohol consumption  Litres per capita (15+)  Australia  2014
# 3    Alcohol consumption  Litres per capita (15+)  Australia  2015
# 4    Alcohol consumption  Litres per capita (15+)  Australia  2016
# ..                   ...                      ...        ...   ...
# 414  Alcohol consumption  Litres per capita (15+)    Croatia  2015
# 415  Alcohol consumption  Litres per capita (15+)    Croatia  2016
# 416  Alcohol consumption  Litres per capita (15+)    Croatia  2017
# 417  Alcohol consumption  Litres per capita (15+)    Croatia  2018
# 418  Alcohol consumption  Litres per capita (15+)    Croatia  2019
#
#      Litres per Person
# 0                 10.0
# 1                  9.9
# 2                  9.7
# 3                  9.8
# 4                  9.5
# ...

# %%
Alcohol_consumption.Measure.value_counts()
# Out:
# Measure
# Litres per capita (15+)    419
# Name: count, dtype: int64

# %%
Correlation2 = pd.merge(Total_Liver_CA_pop, Alcohol_consumption, on = ['Country', 'Year'], how = 'inner')
Correlation2
# Out:
#        Variable_x               Measure_x    Country  Year  Deaths  \
# 0    Liver Cancer  Number of total deaths  Australia  2012  1490.0
# 1    Liver Cancer  Number of total deaths  Australia  2013  1574.0
# 2    Liver Cancer  Number of total deaths  Australia  2014  1732.0
# 3    Liver Cancer  Number of total deaths  Australia  2015  1820.0
# 4    Liver Cancer  Number of total deaths  Australia  2016  1866.0
# ..            ...                     ...        ...   ...     ...
# 357  Liver Cancer  Number of total deaths  Argentina  2015  2003.0
# 358  Liver Cancer  Number of total deaths  Argentina  2016  1870.0
# 359  Liver Cancer  Number of total deaths  Argentina  2017  1985.0
# 360  Liver Cancer  Number of total deaths  Argentina  2018  1901.0
# 361  Liver Cancer  Number of total deaths  Argentina  2019  1922.0
#
#      Population  Total Deaths Percent           Variable_y  \
# 0      22733465              0.006554  Alcohol consumption
# ...

# %%
Correlation2[['Total Deaths Percent', 'Litres per Person']].corr()
# Out:
#                       Total Deaths Percent  Litres per Person
# Total Deaths Percent              1.000000           0.232938
# Litres per Person                 0.232938           1.000000

# %% [markdown]
# # A correlation coefficient of 0.23 indicates a weak positive relationship between the variables. While it suggests some association between the variables, it's important to interpret it cautiously

# %% [markdown]
# # Liver Cancer Deaths table

# %%
pivot_df = Total_Liver_CA_pop.pivot_table(index='Country', columns='Year', values='Deaths')

plt.figure(figsize=(12, 10))
sns.heatmap(pivot_df, cmap='YlGnBu', annot=True, fmt=".1f", linewidths=.5)
plt.title('Liver Cancer Deaths by Year')
plt.xlabel('Year')
plt.ylabel('Country')
plt.show();

# %%
pivot_df = Total_Liver_CA_pop.pivot_table(index='Country', columns='Year', values='Total Deaths Percent')

plt.figure(figsize=(12, 10))
sns.heatmap(pivot_df, cmap='YlGnBu', annot=True, fmt=".5f", linewidths=.5)
plt.title('Lung Cancer % of Deaths')
plt.xlabel('Year')
plt.ylabel('Country')
plt.show();

# %% [markdown]
# # Alcohol Consumption table

# %%
#alphabetical
pivot_df = Alcohol_consumption.pivot_table(index='Country', columns='Year', values='Litres per Person')

plt.figure(figsize=(12, 10))
sns.heatmap(pivot_df, cmap='YlGnBu', annot=True, fmt=".1f", linewidths=.5)
plt.title('Litres per Person by Year age 15+')
plt.xlabel('Year')
plt.ylabel('Country')
plt.show();

# %%
#Total_Lung_CA_pop

#Daily_Smokers

#Total_Liver_CA_pop

#Alcohol_consumption

#Correlation1

#Correlation2

# %% [markdown]
# # Focusing just on the US

# %%
Total_US_Lung_CA_pop = Total_Lung_CA_pop.loc[Total_Lung_CA_pop.Country == "United States"]
Total_US_Lung_CA_pop = Total_US_Lung_CA_pop.reset_index(drop=True)
Total_US_Lung_CA_pop
# Out:
#       Variable                 Measure        Country  Year    Deaths  \
# 0  Lung Cancer  Number of total deaths  United States  2012  157499.0
# 1  Lung Cancer  Number of total deaths  United States  2013  156252.0
# 2  Lung Cancer  Number of total deaths  United States  2014  155610.0
# 3  Lung Cancer  Number of total deaths  United States  2015  153819.0
# 4  Lung Cancer  Number of total deaths  United States  2016  148945.0
# 5  Lung Cancer  Number of total deaths  United States  2017  145932.0
# 6  Lung Cancer  Number of total deaths  United States  2018  142161.0
# 7  Lung Cancer  Number of total deaths  United States  2019  139682.0
# 8  Lung Cancer  Number of total deaths  United States  2020  136166.0
#
#    Population  Total Deaths Percent
# 0   312238050              0.050442
# 1   314549418              0.049675
# 2   316775507              0.049123
# 3   319528204              0.048139
# 4   321553940              0.046320
# 5   324076293              0.045030
# ...

# %%
Total_US_Lung_CA_pop.dtypes
# Out:
# Variable                 object
# Measure                  object
# Country                  object
# Year                      int64
# Deaths                  float64
# Population                int64
# Total Deaths Percent    float64
# dtype: object

# %%
US_Lung_Join = pd.merge(Total_US_Lung_CA_pop, Daily_Smokers, on = ['Country', 'Year'], how = 'inner')
US_Lung_Join
# Out:
#     Variable_x               Measure_x        Country  Year    Deaths  \
# 0  Lung Cancer  Number of total deaths  United States  2012  157499.0
# 1  Lung Cancer  Number of total deaths  United States  2013  156252.0
# 2  Lung Cancer  Number of total deaths  United States  2014  155610.0
# 3  Lung Cancer  Number of total deaths  United States  2015  153819.0
# 4  Lung Cancer  Number of total deaths  United States  2016  148945.0
# 5  Lung Cancer  Number of total deaths  United States  2017  145932.0
# 6  Lung Cancer  Number of total deaths  United States  2018  142161.0
# 7  Lung Cancer  Number of total deaths  United States  2019  139682.0
# 8  Lung Cancer  Number of total deaths  United States  2020  136166.0
#
#    Population  Total Deaths Percent           Variable_y  \
# 0   312238050              0.050442  Tobacco consumption
# 1   314549418              0.049675  Tobacco consumption
# 2   316775507              0.049123  Tobacco consumption
# ...

# %% [markdown]
# #  A correlation coefficient of 0.925 indicates a very strong positive relationship between the variables. It suggests a highly consistent association.

# %%
US_Lung_Join[['Total Deaths Percent', 'Percent of Smokers']].corr()
# Out:
#                       Total Deaths Percent  Percent of Smokers
# Total Deaths Percent              1.000000            0.925324
# Percent of Smokers                0.925324            1.000000

# %%
Total_US_Liver_CA_pop = Total_Liver_CA_pop.loc[Total_Liver_CA_pop.Country == "United States"]
Total_US_Liver_CA_pop = Total_US_Liver_CA_pop.reset_index(drop=True)
Total_US_Liver_CA_pop
# Out:
#        Variable                 Measure        Country  Year   Deaths  \
# 0  Liver Cancer  Number of total deaths  United States  2012  22973.0
# 1  Liver Cancer  Number of total deaths  United States  2013  24032.0
# 2  Liver Cancer  Number of total deaths  United States  2014  24698.0
# 3  Liver Cancer  Number of total deaths  United States  2015  25761.0
# 4  Liver Cancer  Number of total deaths  United States  2016  26569.0
# 5  Liver Cancer  Number of total deaths  United States  2017  27106.0
# 6  Liver Cancer  Number of total deaths  United States  2018  27686.0
# 7  Liver Cancer  Number of total deaths  United States  2019  27959.0
# 8  Liver Cancer  Number of total deaths  United States  2020  28227.0
#
#    Population  Total Deaths Percent
# 0   312238050              0.007358
# 1   314549418              0.007640
# 2   316775507              0.007797
# 3   319528204              0.008062
# 4   321553940              0.008263
# 5   324076293              0.008364
# ...

# %%
US_Liver_Join = pd.merge(Total_US_Liver_CA_pop, Alcohol_consumption, on = ['Country', 'Year'], how = 'inner')
US_Liver_Join
# Out:
#      Variable_x               Measure_x        Country  Year   Deaths  \
# 0  Liver Cancer  Number of total deaths  United States  2012  22973.0
# 1  Liver Cancer  Number of total deaths  United States  2013  24032.0
# 2  Liver Cancer  Number of total deaths  United States  2014  24698.0
# 3  Liver Cancer  Number of total deaths  United States  2015  25761.0
# 4  Liver Cancer  Number of total deaths  United States  2016  26569.0
# 5  Liver Cancer  Number of total deaths  United States  2017  27106.0
# 6  Liver Cancer  Number of total deaths  United States  2018  27686.0
# 7  Liver Cancer  Number of total deaths  United States  2019  27959.0
# 8  Liver Cancer  Number of total deaths  United States  2020  28227.0
#
#    Population  Total Deaths Percent           Variable_y  \
# 0   312238050              0.007358  Alcohol consumption
# 1   314549418              0.007640  Alcohol consumption
# 2   316775507              0.007797  Alcohol consumption
# ...

# %% [markdown]
# # A correlation coefficient of 0.60 indicates a moderate positive relationship between the variables. It suggests a meaningful association.

# %%
US_Liver_Join[['Total Deaths Percent', 'Litres per Person']].corr()
# Out:
#                       Total Deaths Percent  Litres per Person
# Total Deaths Percent              1.000000           0.601525
# Litres per Person                 0.601525           1.000000

# %% [markdown]
# # Let's correlate world liver cancer deaths to smoking

# %%
world_Liver_CA_smoking = pd.merge(Total_Liver_CA_pop, Daily_Smokers, on = ['Country', 'Year'], how = 'inner')
world_Liver_CA_smoking
# Out:
#        Variable_x               Measure_x    Country  Year  Deaths  \
# 0    Liver Cancer  Number of total deaths  Australia  2013  1574.0
# 1    Liver Cancer  Number of total deaths  Australia  2016  1866.0
# 2    Liver Cancer  Number of total deaths  Australia  2019  2205.0
# 3    Liver Cancer  Number of total deaths    Austria  2014   899.0
# 4    Liver Cancer  Number of total deaths    Austria  2019   871.0
# ..            ...                     ...        ...   ...     ...
# 200  Liver Cancer  Number of total deaths    Croatia  2019   497.0
# 201  Liver Cancer  Number of total deaths  Argentina  2015  2003.0
# 202  Liver Cancer  Number of total deaths  Argentina  2018  1901.0
# 203  Liver Cancer  Number of total deaths  Argentina  2019  1922.0
# 204  Liver Cancer  Number of total deaths  Argentina  2020  2031.0
#
#      Population  Total Deaths Percent           Variable_y  \
# 0      23128129              0.006806  Tobacco consumption
# ...

# %% [markdown]
# # A correlation coefficient of 0.275 indicates a weak positive relationship between the variables. It suggests a slight association

# %%
world_Liver_CA_smoking[['Total Deaths Percent', 'Percent of Smokers']].corr()
# Out:
#                       Total Deaths Percent  Percent of Smokers
# Total Deaths Percent              1.000000            0.275546
# Percent of Smokers                0.275546            1.000000

# %% [markdown]
# # Let's correlate world lung CA to alcohol consumption

# %%
world_Lung_CA_alcohol = pd.merge(Total_Lung_CA_pop, Alcohol_consumption, on = ['Country', 'Year'], how = 'inner')
world_Lung_CA_alcohol
# Out:
#       Variable_x               Measure_x    Country  Year  Deaths  Population  \
# 0    Lung Cancer  Number of total deaths  Australia  2012  8138.0    22733465
# 1    Lung Cancer  Number of total deaths  Australia  2013  8215.0    23128129
# 2    Lung Cancer  Number of total deaths  Australia  2014  8252.0    23475686
# 3    Lung Cancer  Number of total deaths  Australia  2015  8470.0    23815995
# 4    Lung Cancer  Number of total deaths  Australia  2016  8411.0    24190907
# ..           ...                     ...        ...   ...     ...         ...
# 357  Lung Cancer  Number of total deaths    Croatia  2014  2827.0     4283972
# 358  Lung Cancer  Number of total deaths    Croatia  2015  2821.0     4254815
# 359  Lung Cancer  Number of total deaths    Croatia  2016  2866.0     4223751
# 360  Lung Cancer  Number of total deaths    Croatia  2017  2994.0     4192467
# 361  Lung Cancer  Number of total deaths    Croatia  2019  2874.0     4129752
#
# ...

# %% [markdown]
# # A correlation coefficient of 0.55 indicates a moderate positive relationship between the variables

# %%
world_Lung_CA_alcohol[['Total Deaths Percent', 'Litres per Person']].corr()
# Out:
#                       Total Deaths Percent  Litres per Person
# Total Deaths Percent              1.000000           0.554759
# Litres per Person                 0.554759           1.000000

# %% [markdown]
# # Finally lets correltate US lung CA to alcohol consumption

# %%
US_Lung_alcohol = pd.merge(Total_US_Lung_CA_pop, Alcohol_consumption, on = ['Country', 'Year'], how = 'inner')
US_Lung_alcohol
# Out:
#     Variable_x               Measure_x        Country  Year    Deaths  \
# 0  Lung Cancer  Number of total deaths  United States  2012  157499.0
# 1  Lung Cancer  Number of total deaths  United States  2013  156252.0
# 2  Lung Cancer  Number of total deaths  United States  2014  155610.0
# 3  Lung Cancer  Number of total deaths  United States  2015  153819.0
# 4  Lung Cancer  Number of total deaths  United States  2016  148945.0
# 5  Lung Cancer  Number of total deaths  United States  2017  145932.0
# 6  Lung Cancer  Number of total deaths  United States  2018  142161.0
# 7  Lung Cancer  Number of total deaths  United States  2019  139682.0
# 8  Lung Cancer  Number of total deaths  United States  2020  136166.0
#
#    Population  Total Deaths Percent           Variable_y  \
# 0   312238050              0.050442  Alcohol consumption
# 1   314549418              0.049675  Alcohol consumption
# 2   316775507              0.049123  Alcohol consumption
# ...

# %% [markdown]
# # A correlation coefficient of -0.79 indicates a strong negative relationship between the variables. It suggests a highly consistent inverse association.

# %%
US_Lung_alcohol[['Total Deaths Percent', 'Litres per Person']].corr()
# Out:
#                       Total Deaths Percent  Litres per Person
# Total Deaths Percent              1.000000          -0.791589
# Litres per Person                -0.791589           1.000000

# %% [markdown]
# # Finally lets correltate US liver CA to smoking

# %%
US_Liver_smoking = pd.merge(Total_US_Liver_CA_pop, Daily_Smokers, on = ['Country', 'Year'], how = 'inner')
US_Liver_smoking
# Out:
#      Variable_x               Measure_x        Country  Year   Deaths  \
# 0  Liver Cancer  Number of total deaths  United States  2012  22973.0
# 1  Liver Cancer  Number of total deaths  United States  2013  24032.0
# 2  Liver Cancer  Number of total deaths  United States  2014  24698.0
# 3  Liver Cancer  Number of total deaths  United States  2015  25761.0
# 4  Liver Cancer  Number of total deaths  United States  2016  26569.0
# 5  Liver Cancer  Number of total deaths  United States  2017  27106.0
# 6  Liver Cancer  Number of total deaths  United States  2018  27686.0
# 7  Liver Cancer  Number of total deaths  United States  2019  27959.0
# 8  Liver Cancer  Number of total deaths  United States  2020  28227.0
#
#    Population  Total Deaths Percent           Variable_y  \
# 0   312238050              0.007358  Tobacco consumption
# 1   314549418              0.007640  Tobacco consumption
# 2   316775507              0.007797  Tobacco consumption
# ...

# %% [markdown]
# # A correlation coefficient of -0.956 indicates a very strong negative relationship between the variables. It suggests a highly consistent and inverse association.

# %%
US_Liver_smoking[['Total Deaths Percent', 'Percent of Smokers']].corr()
# Out:
#                       Total Deaths Percent  Percent of Smokers
# Total Deaths Percent              1.000000           -0.956651
# Percent of Smokers               -0.956651            1.000000

# %%
#Healthcare_coverage_clean

#US_Healthcare_coverage

#vaping_clean

#cancer_clean

#Determinants_of_health_clean

#Health_Status_clean

#US_Health_Status

#Health_Status_Cancer

#Total_populations

#Total_Lung_CA_pop (world percent of people who died by Lung CA)

#Daily_Smokers (percent of daily smokers over age +15)

#Total_Liver_CA_pop (World percent of people who died by Liver CA)

#Alcohol_consumption

#Total_US_Lung_CA_pop (In US percent of people who died by Lung CA)

#Total_US_Liver_CA_pop (In US percent of people who died by Liver CA)

# %%
#Total_Lung_CA_pop.to_csv('../data/Total_Lung_CA_pop.csv', index = False)

# %%
#Daily_Smokers.to_csv('../data/Daily_Smokers.csv', index = False)

# %%
#Total_Liver_CA_pop.to_csv('../data/Total_Liver_CA_pop.csv', index = False)

# %%
#Alcohol_consumption.to_csv('../data/Alcohol_consumption.csv', index = False)

# %%
#Total_US_Lung_CA_pop.to_csv('../data/Total_US_Lung_CA_pop.csv', index = False)

# %%
#Total_US_Liver_CA_pop.to_csv('../data/Total_US_Liver_CA_pop.csv', index = False)

# %%
#US_Lung_Join.to_csv('../data/US_Lung_Join.csv', index = False)

# %%
#US_Liver_Join.to_csv('../data/US_Liver_Join.csv', index = False)

# %%
#world_Liver_CA_smoking.to_csv('../data/world_Liver_CA_smoking.csv', index = False)

# %%
#world_Lung_CA_alcohol.to_csv('../data/world_Lung_CA_alcohol.csv', index = False)

# %%
#US_Liver_smoking.to_csv('../data/US_Liver_smoking.csv', index = False)

# %%
#US_Lung_alcohol.to_csv('../data/US_Lung_alcohol.csv', index = False)
